# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('../output/2021/Munich_GHGco_v2_3_year2021.gpkg')

# %%
gdf
# Out:
#           id ISO3  Year GNFR_Sector SourceType      Identifier           CO2  \
# 0       97.0  DEU  2021           D          A            None  1.116205e+02
# 1       97.0  DEU  2021  HR_outdoor          A            None  4.794204e+01
# 2       97.0  DEU  2021       F_hot          A            None  0.000000e+00
# 3       97.0  DEU  2021           K          A            None  0.000000e+00
# 4       97.0  DEU  2021           J          A            None  0.000000e+00
# ...      ...  ...   ...         ...        ...             ...           ...
# 297100   NaN  DEU  2021           A          P    hkw_freimann  2.194000e+08
# 297101   NaN  DEU  2021           A          P  hw_koppstrasse  1.090000e+07
# 297102   NaN  DEU  2021           A          P      hw_perlach  3.570000e+07
# 297103   NaN  DEU  2021           A          P         hw_riem  3.100000e+06
# 297104   NaN  DEU  2021           A          P      hw_freiham  1.430000e+07
#
# ...

# %%
A = gpd.read_file('../data/GNFR A/2024/2024_GNFR_A.gpkg')

# %%
A
# Out:
#                        name          CO2            CO            NOx  \
# 0          hkw_nord_block_1  350000000.0  15233.280211  220469.033357
# 1          hkw_nord_block_2  826700000.0  23812.436268  316861.834428
# 2          hkw_nord_block_3  270000000.0  30991.645478  177875.045405
# 3               hkw_nord_hw    1900000.0     13.571429     515.714286
# 4            hkw_sued_GuD_1    1400000.0     38.888889    1135.555556
# 5            hkw_sued_GuD_2  507400000.0  14615.253614  194478.885677
# 6       hw_theresienstrasse   11200000.0    373.333333    3792.280702
# 7        hw_gaisbergstrasse    6500000.0    162.754304    2339.593114
# 8   hkw_kathi_kobus_strasse     400000.0      4.000000     200.000000
# 9              hkw_freimann  119400000.0    970.870185   27797.546362
# 10           hw_koppstrasse    5900000.0    338.216561    2559.171975
# 11               hw_perlach    9700000.0     95.802469    3814.135802
# ...

# %%
len(gdf[gdf['GNFR_Sector']=='A'])
# Out:
# 14
