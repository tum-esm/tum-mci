# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('../output/2019/Munich_GHGco_v2_3_year2019.gpkg')

# %%
gdf
# Out:
#           id ISO3  Year GNFR_Sector SourceType      Identifier           CO2  \
# 0       97.0  DEU  2019           D          A            None  5.505849e-01
# 1       97.0  DEU  2019  HR_outdoor          A            None  4.794204e+01
# 2       97.0  DEU  2019       F_hot          A            None  0.000000e+00
# 3       97.0  DEU  2019           K          A            None  0.000000e+00
# 4       97.0  DEU  2019           J          A            None  0.000000e+00
# ...      ...  ...   ...         ...        ...             ...           ...
# 297027   NaN  DEU  2019           A          P    hkw_freimann  7.000000e+06
# 297028   NaN  DEU  2019           A          P  hw_koppstrasse  4.000000e+06
# 297029   NaN  DEU  2019           A          P      hw_perlach  2.320000e+07
# 297030   NaN  DEU  2019           A          P         hw_riem  1.700000e+06
# 297031   NaN  DEU  2019           A          P      hw_freiham  5.000000e+06
#
# ...
