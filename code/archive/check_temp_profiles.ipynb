# %%
import pandas as pd

# %%
resp = pd.read_csv('../data/Human Respiration/time_profile_1h_combined_approach.csv')

# %%
resp['CO2_resid_normalized']
# Out:
# np.float64(8759.999999997595)

# %%
(365*24)
# Out:
# 8760

# %%
(resp['CO2_resid_normalized']*8760).plot()
# Out:
# <Axes: >
